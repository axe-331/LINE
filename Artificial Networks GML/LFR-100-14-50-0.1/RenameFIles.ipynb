# %%
import os

# %%
folder = '/home/ericcamacho/Documentos/LINE/Artificial Networks GML/'
for dirname, dirs, files in os.walk(folder):
    print(dirname)
    for filename in files:
        if filename == 'rede.gml':
            os.rename(dirname+'/rede.gml', dirname+'/network.gml') 
        if filename == 'caracteristicas_globais.csv':
            os.rename(dirname+'/caracteristicas_globais.csv', dirname+'/global_features.csv')
# Out:
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-500-91-250-0.5
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-500-36-250-0.3
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-100-9-50-0.1
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-500-61-250-0.1
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-500-101-250-0.5
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-500-51-250-0.1
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-500-86-250-0.3
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-100-19-50-0.1
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-250-9-125-0.1
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-500-181-250-0.9
# /home/ericcamacho/Documentos/LINE/Artificial Networks GML/LFR-500-31-250-0.5
# ...
